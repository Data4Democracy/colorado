# %% [markdown]
# # Investigating how the number of Oil & Gas Drilling permits changed over the past year (June 2016-June 2017)
# * Has the new administration had an effect on the permit approval process?
# * Has the number of permit requests increased?

# %%
* Has the number of permit requests increased

# %%
from __future__ import division
import pandas as pd
import numpy as np
from datetime import timedelta
import pymc3 as pm
import theano.tensor as tt
import matplotlib.pyplot as plt
import matplotlib as mpl
from pylab import rcParams
# %matplotlib inline

# %% [markdown]
# ## Data Import

# %%
# Import Colorado Oil & Gas Well permits approved 6/8/16 - 6/30/17
# https://cogcc.state.co.us/COGIS/drillingpermits.asp
df_wells = pd.read_csv("data/CO_Well_Permits_2016-06-08_2017-06-30.csv")

df_wells.head()
# Out:
#          Received\nPosted   Operator Name\nNumber  \
# 0  03/29/2017\n04/10/2017  PDC ENERGY INC\n69175
# 1  03/29/2017\n04/10/2017  PDC ENERGY INC\n69175
# 2  03/29/2017\n04/10/2017  PDC ENERGY INC\n69175
# 3  03/29/2017\n04/10/2017  PDC ENERGY INC\n69175
# 4  03/29/2017\n04/10/2017  PDC ENERGY INC\n69175
#
#               Operator Contact Approved Date\nAPI No.\n(Scout Card Link)  \
# 0  Ally Gale \n(303) 831-3931                06/30/2017\n05-123-45084-00
# 1  Ally Gale \n(303) 831-3931                06/30/2017\n05-123-45081-00
# 2  Ally Gale \n(303) 831-3931                06/30/2017\n05-123-45082-00
# 3  Ally Gale \n(303) 831-3931                06/30/2017\n05-123-45083-00
# 4  Ally Gale \n(303) 831-3931                06/30/2017\n05-123-45085-00
#
#   Type of Permit   Well Name/Number Objective Formation  Proposed TD  \
# 0            DR   Schmier\n32H-232            NIOBRARA         16739
# 1            DR   Schmier\n32H-302            NIOBRARA         17054
# 2            DR   Schmier\n32i-302            NIOBRARA         16917
# 3            DR   Schmier\n32i-212            NIOBRARA         16744
# 4            DR   Schmier\n32i-312            NIOBRARA         16800
#
#     Well Location     Footage Call               Field County
# 0  SWSW 32 5N 64W  704 FSL 347 FWL  WATTENBERG\n90750   WELD
# 1  SWSW 32 5N 64W  719 FSL 347 FWL  WATTENBERG\n90750   WELD
# 2  SWSW 32 5N 64W  659 FSL 347 FWL  WATTENBERG\n90750   WELD
# 3  SWSW 32 5N 64W  674 FSL 347 FWL  WATTENBERG\n90750   WELD
# 4  SWSW 32 5N 64W  689 FSL 347 FWL  WATTENBERG\n90750   WELD

# %% [markdown]
# ## Data Clean up

# %%
def cleanup(df):
    ''' Cleanup Dataframe prior to analysis'''
    # Grabbing just date portion of column to get App_Received, App_Posted, App_Approved
    df['App_Received'] = df['Received\nPosted'].str.slice(0, 10)
    df['App_Posted'] = df['Received\nPosted'].str.slice(11, 21)
    df['App_Approved'] = df['Approved Date\nAPI No.\n(Scout Card Link)'].str.slice(0,10)
    
    # Converting App_Received, App_Posted, App_Approved to datetime objects
    df['App_Received'] = pd.to_datetime(df['App_Received'])
    df['App_Posted'] = pd.to_datetime(df['App_Posted'])
    df['App_Approved'] = pd.to_datetime(df['App_Approved'])
    
    # Splitting Operator Name / Number into 2 different columns
    df['Operator Name\nNumber'].str.split()
    df['Operator_Name'] = [df_wells['Operator Name\nNumber'][i]\
                           .split('\n')[0] for i in xrange(len(df_wells))]
    df['Operator_Number'] = [df_wells['Operator Name\nNumber'][i]\
                           .split('\n')[1] for i in \
                           xrange(len(df_wells))]
    
    # Creating Days_Recvd_to_Approval & Days_Posted_to_Approval columns
    df['Days_Recvd_to_Approval'] = (df['App_Approved'] - \
                                    df['App_Received']).dt.days
    df['Days_Posted_to_Approval'] = (df['App_Approved'] - \
                                     df['App_Posted']).dt.days

    # Converting practice name from unicode to ascii
    df['County'] = df['County'].map(lambda x: x.decode("utf8").encode('ascii', 'ignore').decode('ascii'))
    df['Operator Contact'] = df['Operator Contact'].map(lambda x: x.decode("utf8").encode('ascii', 'ignore')\
                                                                   .decode('ascii'))
    df['Type of Permit'] = df['Type of Permit'].map(lambda x: x.decode("utf8").encode('ascii', 'ignore')\
                                                               .decode('ascii'))   
    df['Well Name/Number'] = df['Well Name/Number'].map(lambda x: x.decode("utf8").encode('ascii', 'ignore')\
                                                                   .decode('ascii'))   
    df['Objective Formation'] = df['Objective Formation'].map(lambda x: x.decode("utf8").encode('ascii', 'ignore')\
                                                                         .decode('ascii'))   
    df['Well Location'] = df['Well Location'].map(lambda x: x.decode("utf8").encode('ascii', 'ignore')\
                                                             .decode('ascii'))  
    df['Footage Call'] = df['Footage Call'].map(lambda x: x.decode("utf8").encode('ascii', 'ignore')\
                                                           .decode('ascii'))  
    df['Field'] = df['Field'].map(lambda x: x.decode("utf8").encode('ascii', 'ignore')\
                                             .decode('ascii'))  
 
    # Dropping columns where converted to 2 columns
    df.drop(['Received\nPosted', 'Approved Date\nAPI No.\n(Scout Card Link)', 'Operator Name\nNumber'], \
              axis=1, inplace=True)
    
    # Drop any duplicate rows
    df.drop_duplicates()
    
    return df

# %%
# Run cleanup function on dataframe
df_wells = cleanup(df_wells)

# QC dataframe
df_wells.head()
# Out:
#           Operator Contact Type of Permit  Well Name/Number  \
# 0  AllyGale\n(303)831-3931             DR  Schmier\n32H-232
# 1  AllyGale\n(303)831-3931             DR  Schmier\n32H-302
# 2  AllyGale\n(303)831-3931             DR  Schmier\n32i-302
# 3  AllyGale\n(303)831-3931             DR  Schmier\n32i-212
# 4  AllyGale\n(303)831-3931             DR  Schmier\n32i-312
#
#   Objective Formation  Proposed TD Well Location  Footage Call  \
# 0            NIOBRARA        16739   SWSW325N64W  704FSL347FWL
# 1            NIOBRARA        17054   SWSW325N64W  719FSL347FWL
# 2            NIOBRARA        16917   SWSW325N64W  659FSL347FWL
# 3            NIOBRARA        16744   SWSW325N64W  674FSL347FWL
# 4            NIOBRARA        16800   SWSW325N64W  689FSL347FWL
#
#                Field County App_Received App_Posted App_Approved  \
# 0  WATTENBERG\n90750   WELD   2017-03-29 2017-04-10   2017-06-30
# 1  WATTENBERG\n90750   WELD   2017-03-29 2017-04-10   2017-06-30
# 2  WATTENBERG\n90750   WELD   2017-03-29 2017-04-10   2017-06-30
# 3  WATTENBERG\n90750   WELD   2017-03-29 2017-04-10   2017-06-30
# 4  WATTENBERG\n90750   WELD   2017-03-29 2017-04-10   2017-06-30
#
#     Operator_Name Operator_Number  Days_Recvd_to_Approval  \
# 0  PDC ENERGY INC          69175                       93
# 1  PDC ENERGY INC          69175                       93
# 2  PDC ENERGY INC          69175                       93
# 3  PDC ENERGY INC          69175                       93
# 4  PDC ENERGY INC          69175                       93
#
#    Days_Posted_to_Approval
# 0                       81
# 1                       81
# 2                       81
# 3                       81
# 4                       81

# %%
df_wells.describe()
# Out:
#         Proposed TD  Days_Recvd_to_Approval  Days_Posted_to_Approval
# count   3983.000000             3983.000000              3983.000000
# mean   12806.233994               94.043686                84.000000
# std     3802.486044               72.806550                71.763843
# min     2502.000000                0.000000                 0.000000
# 25%     9445.500000               53.000000                43.000000
# 50%    12967.000000               79.000000                69.000000
# 75%    16133.500000              115.000000               103.000000
# max    21224.000000              757.000000               816.000000

# %%
def histogram_plot(df, data_column):
    # Creating histogram for number of days from the permit being received until approval
    
    # Setting up display parameters
    mpl.rc('xtick', labelsize=12)
    mpl.rc('ytick', labelsize=12)
    mpl.rcParams.update({'font.size': 15})

    data = df[data_column]
    max_bin = ((max(data) / 25) + 1) * 25
    bins = np.arange(0, max_bin, 25)

    fig = plt.figure(figsize=(15, 5))
    ax = fig.add_subplot(1, 1, 1)
    ax.hist(data, bins);
    ax.set_xticks(bins[:-1])
    plt.xticks(rotation='vertical')
    plt.xlim(0,max_bin)
    plt.tick_params(axis='both', which='major', labelsize=11)

# %%
histogram_plot(df_wells, 'Days_Recvd_to_Approval')
plt.title("Histogram of Number of Days from Permit Received until Approved\n");
plt.xlabel("\nNumber of Days until Approved");
plt.ylabel("Number of Permits\n");

# %%
histogram_plot(df_wells, 'Days_Posted_to_Approval')
plt.title("Histogram of Number of Days from Permit Posted until Approved\n");
plt.xlabel("\nNumber of Days until Approved");
plt.ylabel("Number of Permits\n");

# %%
# Wells with 0 days from Received to Approved
print("There were {} permits in this time frame that had 0 days until approval.\n"\
                    .format(len(df_wells[df_wells['Days_Recvd_to_Approval'] == 0])))
print("These counties are represented in this subset: {}".format(df_wells[df_wells['Days_Recvd_to_Approval'] == 0]['County'].unique()))
df_wells[df_wells['Days_Recvd_to_Approval'] == 0]
# Out:
# There were 18 permits in this time frame that had 0 days until approval.
#
# These counties are represented in this subset: [u'WELD' u'LA PLATA' u'LARIMER']
#                       Operator Contact Type of Permit  \
# 163          MattBarber\n(303)312-8188             DR
# 324       PattiCampbell\n(970)335-3828             DR
# 523          KamrinRuder\n(720)9747743             DR
# 919          KamrinRuder\n(720)9747743             DR
# 1797         TyEntenmann\n(720)5578326             DR
# 1851         KamrinRuder\n(720)9747743             DR
# 1985        CHERYLLIGHT\n(720)929-6461             DR
# 2406         ErinEkblad\n(720)616.4319             DR
# 2690        CHERYLLIGHT\n(720)929-6461             DR
# 2768         ErinEkblad\n(720)616.4319             DR
# 3195         KamrinRuder\n(720)9747743             DR
# 3229         KamrinRuder\n(720)9747743             DR
# 3414         KamrinRuder\n(720)9747743             DR
# 3451         KamrinRuder\n(720)9747743             DR
# 3485         KelsiWelch\n(303)831-3974             DR
# 3497         KamrinRuder\n(309)3399466             DR
# 3715       MichaelBrown\n(307)237-9310             DR
# 3852  VenessaLangmacher\n(303)318-6102             DR
#
#                   Well Name/Number Objective Formation  Proposed TD  \
# 163       Peterson\n5-63-30-0758B2            NIOBRARA        16329
# 324               Merry Federal\n2      FRUITLAND COAL         5711
# 523          Johnsons Corner\n13-N            NIOBRARA        17025
# 919                         RBF\n9            NIOBRARA        16812
# 1797                    Kiteley\n9              CODELL        12088
# 1851  TC Country Club West\nC19-11              CODELL        20610
# 1985             JAGUAR\n14N-35HZX            NIOBRARA        17965
# 2406      SRC Williams\n11-4-5NM-C            NIOBRARA        13713
# 2690         HIGHLANDS\n37N-E16HZX            NIOBRARA        14272
# 2768              Evans\n24N-14A-L            NIOBRARA        17022
# 3195               Winder South\n5              CODELL        17174
# 3229                    Winder\n10              CODELL        17395
# 3414                     Winder\n7              CODELL        17337
# 3451                     Winder\n6            NIOBRARA        17106
# 3485         Schaumberg\n17G-214RD            NIOBRARA        12189
# 3497                   Breniman\n9              CODELL        17104
# 3715           Horsetail\n08B-1711            NIOBRARA        15795
# 3852             Cockroft\n19W-314            NIOBRARA        13726
#
#      Well Location    Footage Call                  Field    County  \
# 163    NENE305N63W    613FNL792FEL      WATTENBERG\n90750      WELD
# 324    NWNE1034N6W  1192FNL1567FEL  IGNACIO BLANCO\n38300  LA PLATA
# 523    SWNE355N68W  2444FNL2458FEL      WATTENBERG\n90750   LARIMER
# 919    SENE226N67W   2073FNL300FEL      WATTENBERG\n90750      WELD
# 1797   NWSW213N68W   1369FSL637FWL      WATTENBERG\n90750      WELD
# 1851    SENE85N66W  2446FNL1195FEL      WATTENBERG\n90750      WELD
# 1985   SESW231N67W   365FSL1765FWL      WATTENBERG\n90750      WELD
# 2406    NENW44N67W  1002FNL2406FWL      WATTENBERG\n90750      WELD
# 2690    NENE91N66W   432FNL1038FEL      WATTENBERG\n90750      WELD
# 2768   SWNE265N66W  2005FNL2574FEL      WATTENBERG\n90750      WELD
# 3195    SENE96N67W   2306FNL448FEL      WATTENBERG\n90750      WELD
# 3229    NENE96N67W    910FNL684FEL       SEVERANCE\n77030      WELD
# 3414    NENE96N67W    832FNL684FEL       SEVERANCE\n77030      WELD
# 3451    NENE96N67W    806FNL684FEL       SEVERANCE\n77030      WELD
# 3485   SWNW175N64W  1624FNL1085FWL      WATTENBERG\n90750      WELD
# 3497   NENW166N67W   657FNL2027FWL      WATTENBERG\n90750      WELD
# 3715   NWNE810N57W   380FNL1920FEL         WILDCAT\n99999      WELD
# 3852   SENE195N63W  1399FNL1097FEL      WATTENBERG\n90750      WELD
#
#      App_Received App_Posted App_Approved                    Operator_Name  \
# 163    2017-06-20 2017-06-20   2017-06-20        BARRETT CORPORATION* BILL
# 324    2017-06-12 2017-06-12   2017-06-12    BP AMERICA PRODUCTION COMPANY
# 523    2017-05-22 2017-05-22   2017-05-22         EXTRACTION OIL & GAS LLC
# 919    2017-04-27 2017-04-27   2017-04-27         EXTRACTION OIL & GAS LLC
# 1797   2017-02-09 2017-02-09   2017-02-09         EXTRACTION OIL & GAS LLC
# 1851   2017-02-06 2017-02-06   2017-02-06         EXTRACTION OIL & GAS LLC
# 1985   2017-01-12 2017-01-12   2017-01-12  KERR MCGEE OIL & GAS ONSHORE LP
# 2406   2016-11-29 2016-11-29   2016-11-29    SYNERGY RESOURCES CORPORATION
# 2690   2016-10-24 2016-10-24   2016-10-24  KERR MCGEE OIL & GAS ONSHORE LP
# 2768   2016-10-17 2016-10-17   2016-10-17    SYNERGY RESOURCES CORPORATION
# 3195   2016-09-15 2016-09-15   2016-09-15         EXTRACTION OIL & GAS LLC
# 3229   2016-09-12 2016-09-12   2016-09-12         EXTRACTION OIL & GAS LLC
# 3414   2016-08-19 2016-08-19   2016-08-19         EXTRACTION OIL & GAS LLC
# 3451   2016-08-10 2016-08-10   2016-08-10         EXTRACTION OIL & GAS LLC
# 3485   2016-08-03 2016-08-03   2016-08-03                   PDC ENERGY INC
# 3497   2016-07-29 2016-07-29   2016-07-29         EXTRACTION OIL & GAS LLC
# 3715   2016-07-08 2016-07-08   2016-07-08    WHITING OIL & GAS CORPORATION
# 3852   2016-06-17 2016-06-17   2016-06-17                   PDC ENERGY INC
#
#      Operator_Number  Days_Recvd_to_Approval  Days_Posted_to_Approval
# 163           10071                        0                        0
# 324           10000                        0                        0
# 523           10459                        0                        0
# 919           10459                        0                        0
# 1797          10459                        0                        0
# 1851          10459                        0                        0
# 1985          47120                        0                        0
# 2406          10311                        0                        0
# 2690          47120                        0                        0
# 2768          10311                        0                        0
# 3195          10459                        0                        0
# 3229          10459                        0                        0
# 3414          10459                        0                        0
# 3451          10459                        0                        0
# 3485          69175                        0                        0
# 3497          10459                        0                        0
# 3715          96155                        0                        0
# 3852          69175                        0                        0

# %%
# Wells with 365+ days from Received to Approved
print("There were {} permits in this time frame that had 365+ days until approval.\n"\
                    .format(len(df_wells[df_wells['Days_Recvd_to_Approval'] > 365])))
print("These counties are represented in this subset: {}".format(df_wells[df_wells['Days_Recvd_to_Approval'] > 365]['County'].unique()))
df_wells[df_wells['Days_Recvd_to_Approval'] > 365]
# Out:
# There were 30 permits in this time frame that had 365+ days until approval.
#
# These counties are represented in this subset: [u'WELD']
#                      Operator Contact Type of Permit  \
# 155   ShayelynMarshall\n(720)929-6907             DR
# 156   ShayelynMarshall\n(720)929-6907             DR
# 157   ShayelynMarshall\n(720)929-6907             DR
# 158   ShayelynMarshall\n(720)929-6907             DR
# 159   ShayelynMarshall\n(720)929-6907             DR
# 160   ShayelynMarshall\n(720)929-6907             DR
# 312     ChrisMcRickard\n(720)410-8494             DR
# 313     ChrisMcRickard\n(720)410-8494             DR
# 314     ChrisMcRickard\n(720)410-8494             DR
# 315     ChrisMcRickard\n(720)410-8494             DR
# 316     ChrisMcRickard\n(720)410-8494             DR
# 317     ChrisMcRickard\n(720)410-8494             DR
# 318     ChrisMcRickard\n(720)410-8494             DR
# 319     ChrisMcRickard\n(720)410-8494             DR
# 320     ChrisMcRickard\n(720)410-8494             DR
# 321     ChrisMcRickard\n(720)410-8494             DR
# 322     ChrisMcRickard\n(720)410-8494             DR
# 323     ChrisMcRickard\n(720)410-8494             DR
# 1738      CallieFiddes\n(303)398-0550             DR
# 1740      CallieFiddes\n(303)398-0355             DR
# 1741      CallieFiddes\n(303)398-0550             DR
# 3811      BonnieLamond\n(720)876-5156             DR
# 3812      BonnieLamond\n(720)876-5156             DR
# 3813      BonnieLamond\n(720)876-5156             DR
# 3814      BonnieLamond\n(720)876-5156             DR
# 3815      BonnieLamond\n(720)876-5156             DR
# 3816      BonnieLamond\n(720)876-5156             DR
# 3817      BonnieLamond\n(720)876-5156             DR
# 3818      BonnieLamond\n(720)876-5156             DR
# 3819      BonnieLamond\n(720)876-5156             DR
#
#                     Well Name/Number Objective Formation  Proposed TD  \
# 155   RESOLUTION FED\n12-65-31-6-3NH            NIOBRARA        18454
# 156   RESOLUTION FED\n12-65-31-6-2NH            NIOBRARA        18648
# 157   RESOLUTION FED\n12-65-31-6-4NH            NIOBRARA        18368
# 158     RESOLUTION FED\n12-65-31-6NH            NIOBRARA        19001
# 159       RESOLUTION\n12-65-31-6-6NH            NIOBRARA        18319
# 160       RESOLUTION\n12-65-31-6-7NH            NIOBRARA        18374
# 312       Regnier Farms\n1D-19H-B268            NIOBRARA        11923
# 313       Regnier Farms\n1E-19H-B268              CODELL        12060
# 314       Regnier Farms\n1H-19H-B268              CODELL        12125
# 315       Regnier Farms\n1I-19H-B268            NIOBRARA        11931
# 316       Regnier Farms\n1J-19H-B268            NIOBRARA        12057
# 317       Regnier Farms\n1K-19H-B268              CODELL        12228
# 318       Regnier Farms\n1A-19H-B268            NIOBRARA        11955
# 319       Regnier Farms\n1B-19H-B268              CODELL        12069
# 320       Regnier Farms\n1C-19H-B268            NIOBRARA        11845
# 321       Regnier Farms\n1L-19H-B268            NIOBRARA        12065
# 322       Regnier Farms\n1F-19H-B268            NIOBRARA        11854
# 323       Regnier Farms\n1G-19H-B268            NIOBRARA        11963
# 1738            Simpson FD\n16-339HN            NIOBRARA        14892
# 1740            Simpson FD\n16-379HC              CODELL        17714
# 1741            Simpson FD\n16-339HC              CODELL        15077
# 3811        Morgan Hills\n1F-7H-A168              CODELL        17664
# 3812        Morgan Hills\n1D-7H-A168              CODELL        17701
# 3813        Morgan Hills\n1G-7H-A168            NIOBRARA        17411
# 3814        Morgan Hills\n1A-7H-A168            NIOBRARA        17590
# 3815        Morgan Hills\n1B-7H-A168              CODELL        17776
# 3816        Morgan Hills\n1C-7H-A168            NIOBRARA        17490
# 3817        Morgan Hills\n1H-7H-A168              CODELL        17653
# 3818        Morgan Hills\n1E-7H-A168            NIOBRARA        17440
# 3819        Morgan Hills\n1I-7H-A168            NIOBRARA        17421
#
#      Well Location    Footage Call              Field County App_Received  \
# 155   NWNE3112N65W   556FNL2640FEL     WILDCAT\n99999   WELD   2015-09-11
# 156   NWNE3112N65W   534FNL2660FEL     WILDCAT\n99999   WELD   2015-09-11
# 157   NWNE3112N65W   579FNL2621FEL     WILDCAT\n99999   WELD   2015-09-11
# 158   NENW3112N65W   511FNL2625FWL     WILDCAT\n99999   WELD   2015-09-11
# 159   NWNE3112N65W   330FNL1725FEL     WILDCAT\n99999   WELD   2015-09-11
# 160   NWNE3112N65W   330FNL1665FEL     WILDCAT\n99999   WELD   2015-09-11
# 312    NWNE192N68W    62FNL1823FEL  WATTENBERG\n90750   WELD   2015-06-11
# 313    NWNE192N68W    62FNL1813FEL  WATTENBERG\n90750   WELD   2015-06-11
# 314    NWNE192N68W    62FNL1783FEL  WATTENBERG\n90750   WELD   2015-06-11
# 315    NWNE192N68W    62FNL1773FEL  WATTENBERG\n90750   WELD   2015-06-11
# 316    NWNE192N68W    62FNL1763FEL  WATTENBERG\n90750   WELD   2015-06-11
# 317    NWNE192N68W    62FNL1753FEL  WATTENBERG\n90750   WELD   2015-06-11
# 318    NWNE192N68W    62FNL1853FEL  WATTENBERG\n90750   WELD   2015-06-11
# 319    NWNE192N68W    62FNL1843FEL  WATTENBERG\n90750   WELD   2015-06-11
# 320    NWNE192N68W    62FNL1833FEL  WATTENBERG\n90750   WELD   2015-06-11
# 321    NWNE192N68W    62FNL1743FEL  WATTENBERG\n90750   WELD   2015-06-11
# 322    NWNE192N68W    62FNL1803FEL  WATTENBERG\n90750   WELD   2015-06-11
# 323    NWNE192N68W    62FNL1793FEL  WATTENBERG\n90750   WELD   2015-06-11
# 1738   SENE156N67W  2136FNL1029FEL  WATTENBERG\n90750   WELD   2015-01-20
# 1740   SENE156N67W  2136FNL1074FEL  WATTENBERG\n90750   WELD   2015-01-20
# 1741   SENE156N67W  2136FNL1044FEL  WATTENBERG\n90750   WELD   2015-01-21
# 3811    NENE71N68W    368FNL349FEL  WATTENBERG\n90750   WELD   2015-01-12
# 3812    NENE71N68W    368FNL369FEL  WATTENBERG\n90750   WELD   2015-01-12
# 3813    NENE71N68W    368FNL339FEL  WATTENBERG\n90750   WELD   2015-01-12
# 3814    NENE71N68W    368FNL399FEL  WATTENBERG\n90750   WELD   2015-01-12
# 3815    NENE71N68W    368FNL389FEL  WATTENBERG\n90750   WELD   2015-01-12
# 3816    NENE71N68W    368FNL379FEL  WATTENBERG\n90750   WELD   2015-01-12
# 3817    NENE71N68W    368FNL329FEL  WATTENBERG\n90750   WELD   2015-01-12
# 3818    NENE71N68W    368FNL359FEL  WATTENBERG\n90750   WELD   2015-01-12
# 3819    NENE71N68W    368FNL319FEL  WATTENBERG\n90750   WELD   2015-01-12
#
#      App_Posted App_Approved                          Operator_Name  \
# 155  2015-09-15   2017-06-22               ANADARKO E&P ONSHORE LLC
# 156  2015-09-15   2017-06-22               ANADARKO E&P ONSHORE LLC
# 157  2015-09-15   2017-06-22               ANADARKO E&P ONSHORE LLC
# 158  2015-09-15   2017-06-22               ANADARKO E&P ONSHORE LLC
# 159  2015-09-14   2017-06-22               ANADARKO E&P ONSHORE LLC
# 160  2015-09-14   2017-06-22               ANADARKO E&P ONSHORE LLC
# 312  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 313  2015-03-23   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 314  2015-03-23   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 315  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 316  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 317  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 318  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 319  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 320  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 321  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 322  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 323  2015-03-20   2017-06-13  CRESTONE PEAK RESOURCES OPERATING LLC
# 1738 2016-10-11   2017-02-15    GREAT WESTERN OPERATING COMPANY LLC
# 1740 2016-10-11   2017-02-15    GREAT WESTERN OPERATING COMPANY LLC
# 1741 2016-10-11   2017-02-15    GREAT WESTERN OPERATING COMPANY LLC
# 3811 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
# 3812 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
# 3813 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
# 3814 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
# 3815 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
# 3816 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
# 3817 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
# 3818 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
# 3819 2015-01-13   2016-06-22             ENCANA OIL & GAS (USA) INC
#
#      Operator_Number  Days_Recvd_to_Approval  Days_Posted_to_Approval
# 155            2800                      650                      646
# 156            2800                      650                      646
# 157            2800                      650                      646
# 158            2800                      650                      646
# 159            2800                      650                      647
# 160            2800                      650                      647
# 312           10633                      733                      816
# 313           10633                      733                      813
# 314           10633                      733                      813
# 315           10633                      733                      816
# 316           10633                      733                      816
# 317           10633                      733                      816
# 318           10633                      733                      816
# 319           10633                      733                      816
# 320           10633                      733                      816
# 321           10633                      733                      816
# 322           10633                      733                      816
# 323           10633                      733                      816
# 1738          10110                      757                      127
# 1740          10110                      757                      127
# 1741          10110                      756                      127
# 3811         100185                      527                      526
# 3812         100185                      527                      526
# 3813         100185                      527                      526
# 3814         100185                      527                      526
# 3815         100185                      527                      526
# 3816         100185                      527                      526
# 3817         100185                      527                      526
# 3818         100185                      527                      526
# 3819         100185                      527                      526

# %%
# Getting listing of Companies with most well permits approved in this time period
df_wells.groupby('Operator_Name').count()['Well Location'].sort_values(axis=0, ascending=False)
# Out:
# Operator_Name
# TEP ROCKY MOUNTAIN LLC                        505
# PDC ENERGY INC                                371
# EXTRACTION OIL & GAS LLC                      285
# WHITING OIL & GAS CORPORATION                 282
# KERR MCGEE OIL & GAS ONSHORE LP               252
# GREAT WESTERN OPERATING COMPANY LLC           219
# VANGUARD OPERATING LLC                        209
# NOBLE ENERGY INC                              152
# CAERUS PICEANCE LLC                           149
# BARRETT CORPORATION* BILL                     142
# LARAMIE ENERGY LLC                            125
# URSA OPERATING COMPANY LLC                    119
# SYNERGY RESOURCES CORPORATION                 111
# BP AMERICA PRODUCTION COMPANY                 101
# ENCANA OIL & GAS (USA) INC                     93
# BONANZA CREEK ENERGY OPERATING COMPANY LLC     76
# CAERUS WASHCO LLC                              70
# SANDRIDGE EXPLORATION & PRODUCTION LLC         54
# EXTRACTION OIL & GAS INC                       51
# HRM RESOURCES II LLC                           47
# ENERPLUS RESOURCES (USA) CORPORATION           42
# CRESTONE PEAK RESOURCES OPERATING LLC          36
# BAYSWATER EXPLORATION AND PRODUCTION LLC       36
# CRESCENT POINT ENERGY U.S. CORP                34
# CHEVRON USA INC                                30
# LONGS PEAK RESOURCES LLC                       29
# WARD PETROLEUM CORPORATION                     28
# EDGE ENERGY LLC                                27
# PETRO OPERATING COMPANY LLC                    24
# SG INTERESTS I LTD                             21
#                                              ...
# COLEMAN OIL & GAS INC                           6
# CARRIZO NIOBRARA LLC                            6
# MENDELL FINISTERRE II LLC                       5
# EXPEDITION WATER SOLUTIONS COLORADO LLC         4
# NGL WATER SOLUTIONS DJ LLC                      4
# HIGHLANDS NATURAL RESOURCES CORPORATION         4
# CPX II OPERATING LLC                            3
# BISON OIL & GAS LLC                             3
# AGAVE OIL & GAS LLC                             3
# WIEPKING-FULLERTON ENERGY LLC                   3
# MULL DRILLING COMPANY INC                       3
# INVESTMENT EQUIPMENT LLC                        2
# LARIO OIL & GAS COMPANY                         2
# AUGUSTUS ENERGY PARTNERS II LLC                 2
# AUS-TEX EXPLORATION INC                         2
# EASTCO OPERATING LLC                            1
# STELBAR OIL CORP INC                            1
# WESCO OPERATING INC                             1
# WASTE MANAGEMENT OF COLORADO INC                1
# WARD & SON* ALFRED                              1
# SUNBURST INC                                    1
# SCHNEIDER ENERGY SERVICES INC                   1
# ST CROIX OPERATING INC                          1
# GREENLEAF ENVIRONMENTAL SERVICES LLC            1
# QEP ENERGY COMPANY                              1
# PROSPECT ENERGY LLC                             1
# PETROLEUM RESOURCE MANAGEMENT CORP.             1
# WINDY HILL WATER OPERATIONS LLC                 1
# CONFLUENCE DJ LLC                               1
# XTO ENERGY INC                                  1
# Name: Well Location, dtype: int64

# %%
# Getting number of wells by County
df_wells.groupby('County').count()['Well Location'].sort_values(axis=0, ascending=False)
# Out:
# County
# WELD          2272
# GARFIELD       948
# RIO BLANCO     157
# ADAMS          142
# MESA           118
# LA PLATA       113
# JACKSON         54
# LARIMER         34
# GUNNISON        30
# ARAPAHOE        23
# MOFFAT          20
# MORGAN          15
# LINCOLN         14
# WASHINGTON      13
# MONTEZUMA        8
# ELBERT           4
# ARCHULETA        4
# CROWLEY          3
# FREMONT          2
# DOLORES          2
# BACA             2
# LOGAN            2
# KIOWA            2
# KIT CARSON       1
# Name: Well Location, dtype: int64

# %%
def line_plot(df, column):
    # Creating line plot
    
    # Setting up display parameters
    mpl.rc('xtick', labelsize=12)
    mpl.rc('ytick', labelsize=12)
    mpl.rcParams.update({'font.size': 15})

    # Plotting Day vs. Average Number of Patients
    x = df.groupby(column).count().index
    y = df.groupby(column).count()['Well Location']

    fig=plt.figure(figsize=(15,7));
    ax=fig.add_subplot(111);
    ax.plot(x, y, color='b', linewidth=1.5);
    plt.xticks(rotation='vertical');

# %%
# Plotting the number Number of Drilling Applications Approved per Day in Colorado
line_plot(df_wells, 'App_Approved')
plt.title("Number of CO Drilling Applications Approved per Day\n");
plt.xlabel('\nDate');
plt.ylabel('Number of Applications');

# %% [markdown]
# ## Visually, it does appear there is an increase in the trend.
# ### Let's apply some Bayesian Probabilistic Programming to gain some more insight.
#
# Thanks to Cameron Davidson-Pilon's 'Bayesian Methods for Hackers' for showing how I can go about doing this.
#
# I see that it makes sense to model the application approval count data per day using a Poisson distribution:
# <center>C<sub>i</sub> ~ Poi( $\lambda$ )</center>
#
# It appears that there is an increasing trend of approval counts per day.
# So, we may have a switchpoint where our $\lambda$ may be changing and we have $\lambda$<sub>1</sub> before the increase in approvals and $\lambda$<sub>2</sub> after the increase in approvals.
#
# We can then model $\lambda$<sub>1</sub> and $\lambda$<sub>2</sub> using Exponential distributions.
#
# The Exponential function has a parameter $\alpha$ that I need to model as well:
# <center>$\lambda$<sub>1</sub> ~ Exp($\alpha$)</center>
# <center>$\lambda$<sub>2</sub> ~ Exp($\alpha$)</center>
#
# A good rule of thumb is to set the exponential parameter, $\alpha$, equal to the inverse of the average number of applications approved per day as this makes the prior probablility less opinionated up front:
# <center>$\alpha$ = $\frac{1}{Ci}$
#
# I'll use a Uniform distribution to model the switchpoint time, $\tau$:
# <center> $\tau$ ~ DiscreteUniform(1, Number of Days)</center>

# %%
# Number of applications approved per day
apps_per_day = df_wells.groupby('App_Approved').count()['Well Location']

num_days = len(apps_per_day)

# Alpha is a hyperparameter needed for the Exponential Distribution
alpha = 1.0 / apps_per_day.mean()

with pm.Model() as model:
    lambda1 = pm.Exponential("lambda1", alpha)
    lambda2 = pm.Exponential('lambda2', alpha)

    tau = pm.DiscreteUniform('tau', lower=0, upper=num_days-1)
    
    print("Random output: ", tau.random(), tau.random(), tau.random())
# Out:
# ('Random output: ', array(87, dtype=int32), array(74, dtype=int32), array(137, dtype=int32))

# %%
# The switch() function assigns lambda1 or lambda2 as the value of lambda_, depending on what side of tau we are on. 
# The values of lambda_ up until tau are lambda_1 and the values afterwards are lambda_2.

with model:
    idx = np.arange(num_days) # Index
    lambda_ = pm.math.switch(tau >= idx, lambda1, lambda2)

# %%
# The variable obs combines apps_per_day with our proposed data-generation scheme, given by the variable lambda_,
#    through the observed keyword.

with model:
    obs = pm.Poisson("obs", lambda_, observed=apps_per_day)

# %%
# Using the Metropolis-Hastings Markov chain Monte Carlo (MCMC) method to obtain a sequence of random samples 
#    from our probability distributions

with model:
    step = pm.Metropolis()
    trace = pm.sample(10000, tune=5000,step=step)
# Out:
# 100%|██████████| 10000/10000 [00:04<00:00, 2421.71it/s]

# %%
lambda1_samples = trace['lambda1']
lambda2_samples = trace['lambda2']
tau_samples = trace['tau']

# %%
#Plotting histogram of the samples:

fig = plt.figure(figsize=(12.5, 10))

ax = plt.subplot(311)
ax.set_autoscaley_on(False)

plt.hist(lambda1_samples, histtype='stepfilled', bins=30, alpha=0.85,
         label="posterior of $\lambda1$", color="#A60628", normed=True)
plt.legend(loc="upper left")
plt.title(r"""Posterior distributions of the variables
    $\lambda1,\;\lambda2,\;\tau$""")
plt.xlim([14, 24])
plt.xlabel("$\lambda1$ value")

ax = plt.subplot(312)
ax.set_autoscaley_on(False)
plt.hist(lambda2_samples, histtype='stepfilled', bins=30, alpha=0.85,
         label="posterior of $\lambda2$", color="#7A68A6", normed=True)
plt.legend(loc="upper left")
plt.xlim([14, 24])
plt.xlabel("$\lambda2$ value")

plt.subplot(313)
w = 1.0 / tau_samples.shape[0] * np.ones_like(tau_samples)
plt.hist(tau_samples, bins=num_days, alpha=1,
         label=r"posterior of $\tau$",
         color="#467821", weights=w, rwidth=2.)
plt.xticks(np.arange(num_days))

plt.legend(loc="upper left")
plt.ylim([0, .75])
plt.xlim(110, 125)
plt.xlabel(r"$\tau$ (in days)")
plt.ylabel("probability");

# %% [markdown]
# ## On Day 116 is when we are seeing the switchpoint.
# ## What day is that?

# %%
# Because Days of Approval do not contain weekends/holidays and such, we need to find the 116th day in our list 
#    of actual approval days
switchpoint_day = sorted(df_wells['App_Approved'].unique())[116]
print("The day where we observe a switchpoint, or increase in average number of permits approved, is {}"\
       .format(switchpoint_day))
# Out:
# The day where we observe a switchpoint, or increase in average number of permits approved, is 2016-12-23T00:00:00.000000000

# %% [markdown]
# ## December 23, 2016 => This is probably the last day of work for the year for most people, right before the holidays

# %%
# Plotting the application counts per day with the Expected Value of Applications Approved per Day graphed on top.

fig = plt.figure(figsize=(12.5, 5))
# tau_samples, lambda_1_samples, lambda_2_samples contain
# N samples from the corresponding posterior distribution

N = tau_samples.shape[0]
expected_approvals_per_day = np.zeros(num_days)
for day in range(0, num_days):
    # ix is a bool index of all tau samples corresponding to
    # the switchpoint occurring prior to value of 'day'
    ix = day < tau_samples
    # Each posterior sample corresponds to a value for tau.
    # For each day, that value of tau indicates whether we're "before"
    # (in the lambda1 "regime") or
    #  "after" (in the lambda2 "regime") the switchpoint.
    # by taking the posterior sample of lambda1/2 accordingly, we can average
    # over all samples to get an expected value for lambda on that day.
    # The "application count" random variable is Poisson distributed,
    # and therefore lambda (the poisson parameter) is the expected value of
    # "application count".
    expected_approvals_per_day[day] = (lambda1_samples[ix].sum()
                                   + lambda2_samples[~ix].sum()) / N


plt.plot(range(num_days), expected_approvals_per_day, lw=4, color="#E24A33",
         label="Expected Number of Permits Approved")
plt.xlim(0, num_days)
plt.xlabel("Day")
plt.ylabel("Expected # of Permits Approved")
plt.title("Expected number of Permits Approved per Day\nJune 2016 - June 2017\n")
# plt.ylim(0, 60)
plt.bar(np.arange(len(apps_per_day)), apps_per_day, color="#348ABD", alpha=0.65,
        label="Observed Approvals per Day")

plt.legend(loc="upper left");

# %%
print df_wells['App_Approved'].unique()
# Out:
# ['2017-06-30T00:00:00.000000000' '2017-06-29T00:00:00.000000000'
#  '2017-06-28T00:00:00.000000000' '2017-06-27T00:00:00.000000000'
#  '2017-06-26T00:00:00.000000000' '2017-06-23T00:00:00.000000000'
#  '2017-06-22T00:00:00.000000000' '2017-06-21T00:00:00.000000000'
#  '2017-06-20T00:00:00.000000000' '2017-06-19T00:00:00.000000000'
#  '2017-06-16T00:00:00.000000000' '2017-06-15T00:00:00.000000000'
#  '2017-06-14T00:00:00.000000000' '2017-06-13T00:00:00.000000000'
#  '2017-06-12T00:00:00.000000000' '2017-06-09T00:00:00.000000000'
#  '2017-06-06T00:00:00.000000000' '2017-06-05T00:00:00.000000000'
#  '2017-06-04T00:00:00.000000000' '2017-06-02T00:00:00.000000000'
#  '2017-06-01T00:00:00.000000000' '2017-05-30T00:00:00.000000000'
#  '2017-05-26T00:00:00.000000000' '2017-05-25T00:00:00.000000000'
#  '2017-05-24T00:00:00.000000000' '2017-05-23T00:00:00.000000000'
#  '2017-05-22T00:00:00.000000000' '2017-05-18T00:00:00.000000000'
#  '2017-05-16T00:00:00.000000000' '2017-05-15T00:00:00.000000000'
#  '2017-05-14T00:00:00.000000000' '2017-05-11T00:00:00.000000000'
#  '2017-05-10T00:00:00.000000000' '2017-05-09T00:00:00.000000000'
#  '2017-05-08T00:00:00.000000000' '2017-05-07T00:00:00.000000000'
#  '2017-05-05T00:00:00.000000000' '2017-05-04T00:00:00.000000000'
#  '2017-05-03T00:00:00.000000000' '2017-04-29T00:00:00.000000000'
#  '2017-04-28T00:00:00.000000000' '2017-04-27T00:00:00.000000000'
#  '2017-04-26T00:00:00.000000000' '2017-04-25T00:00:00.000000000'
#  '2017-04-24T00:00:00.000000000' '2017-04-22T00:00:00.000000000'
#  '2017-04-18T00:00:00.000000000' '2017-04-17T00:00:00.000000000'
#  '2017-04-10T00:00:00.000000000' '2017-04-09T00:00:00.000000000'
#  '2017-04-07T00:00:00.000000000' '2017-04-06T00:00:00.000000000'
#  '2017-04-05T00:00:00.000000000' '2017-04-04T00:00:00.000000000'
#  '2017-04-03T00:00:00.000000000' '2017-03-31T00:00:00.000000000'
#  '2017-03-30T00:00:00.000000000' '2017-03-29T00:00:00.000000000'
#  '2017-03-28T00:00:00.000000000' '2017-03-27T00:00:00.000000000'
#  '2017-03-24T00:00:00.000000000' '2017-03-22T00:00:00.000000000'
#  '2017-03-21T00:00:00.000000000' '2017-03-19T00:00:00.000000000'
#  '2017-03-17T00:00:00.000000000' '2017-03-11T00:00:00.000000000'
#  '2017-03-10T00:00:00.000000000' '2017-03-09T00:00:00.000000000'
#  '2017-03-08T00:00:00.000000000' '2017-03-07T00:00:00.000000000'
#  '2017-03-06T00:00:00.000000000' '2017-03-03T00:00:00.000000000'
#  '2017-03-02T00:00:00.000000000' '2017-03-01T00:00:00.000000000'
#  '2017-02-28T00:00:00.000000000' '2017-02-27T00:00:00.000000000'
#  '2017-02-26T00:00:00.000000000' '2017-02-25T00:00:00.000000000'
#  '2017-02-22T00:00:00.000000000' '2017-02-20T00:00:00.000000000'
#  '2017-02-19T00:00:00.000000000' '2017-02-17T00:00:00.000000000'
#  '2017-02-16T00:00:00.000000000' '2017-02-15T00:00:00.000000000'
#  '2017-02-13T00:00:00.000000000' '2017-02-10T00:00:00.000000000'
#  '2017-02-09T00:00:00.000000000' '2017-02-07T00:00:00.000000000'
#  '2017-02-06T00:00:00.000000000' '2017-01-31T00:00:00.000000000'
#  '2017-01-29T00:00:00.000000000' '2017-01-27T00:00:00.000000000'
#  '2017-01-26T00:00:00.000000000' '2017-01-20T00:00:00.000000000'
#  '2017-01-18T00:00:00.000000000' '2017-01-13T00:00:00.000000000'
#  '2017-01-12T00:00:00.000000000' '2017-01-10T00:00:00.000000000'
#  '2017-01-09T00:00:00.000000000' '2017-01-08T00:00:00.000000000'
#  '2017-01-07T00:00:00.000000000' '2017-01-04T00:00:00.000000000'
#  '2016-12-30T00:00:00.000000000' '2016-12-29T00:00:00.000000000'
#  '2016-12-28T00:00:00.000000000' '2016-12-27T00:00:00.000000000'
#  '2016-12-23T00:00:00.000000000' '2016-12-22T00:00:00.000000000'
#  '2016-12-21T00:00:00.000000000' '2016-12-19T00:00:00.000000000'
#  '2016-12-18T00:00:00.000000000' '2016-12-17T00:00:00.000000000'
#  '2016-12-16T00:00:00.000000000' '2016-12-15T00:00:00.000000000'
#  '2016-12-14T00:00:00.000000000' '2016-12-12T00:00:00.000000000'
#  '2016-12-11T00:00:00.000000000' '2016-12-09T00:00:00.000000000'
#  '2016-12-06T00:00:00.000000000' '2016-11-30T00:00:00.000000000'
#  '2016-11-29T00:00:00.000000000' '2016-11-28T00:00:00.000000000'
#  '2016-11-27T00:00:00.000000000' '2016-11-23T00:00:00.000000000'
#  '2016-11-18T00:00:00.000000000' '2016-11-15T00:00:00.000000000'
#  '2016-11-14T00:00:00.000000000' '2016-11-10T00:00:00.000000000'
#  '2016-11-08T00:00:00.000000000' '2016-11-07T00:00:00.000000000'
#  '2016-11-04T00:00:00.000000000' '2016-11-02T00:00:00.000000000'
#  '2016-11-01T00:00:00.000000000' '2016-10-31T00:00:00.000000000'
#  '2016-10-26T00:00:00.000000000' '2016-10-24T00:00:00.000000000'
#  '2016-10-23T00:00:00.000000000' '2016-10-21T00:00:00.000000000'
#  '2016-10-20T00:00:00.000000000' '2016-10-19T00:00:00.000000000'
#  '2016-10-17T00:00:00.000000000' '2016-10-16T00:00:00.000000000'
#  '2016-10-14T00:00:00.000000000' '2016-10-13T00:00:00.000000000'
#  '2016-10-12T00:00:00.000000000' '2016-10-10T00:00:00.000000000'
#  '2016-10-06T00:00:00.000000000' '2016-10-04T00:00:00.000000000'
#  '2016-10-03T00:00:00.000000000' '2016-10-02T00:00:00.000000000'
#  '2016-10-01T00:00:00.000000000' '2016-09-30T00:00:00.000000000'
#  '2016-09-29T00:00:00.000000000' '2016-09-28T00:00:00.000000000'
#  '2016-09-27T00:00:00.000000000' '2016-09-26T00:00:00.000000000'
#  '2016-09-24T00:00:00.000000000' '2016-09-23T00:00:00.000000000'
#  '2016-09-22T00:00:00.000000000' '2016-09-21T00:00:00.000000000'
#  '2016-09-19T00:00:00.000000000' '2016-09-16T00:00:00.000000000'
#  '2016-09-15T00:00:00.000000000' '2016-09-14T00:00:00.000000000'
#  '2016-09-12T00:00:00.000000000' '2016-09-11T00:00:00.000000000'
#  '2016-09-10T00:00:00.000000000' '2016-09-09T00:00:00.000000000'
#  '2016-09-08T00:00:00.000000000' '2016-09-07T00:00:00.000000000'
#  '2016-09-01T00:00:00.000000000' '2016-08-29T00:00:00.000000000'
#  '2016-08-27T00:00:00.000000000' '2016-08-26T00:00:00.000000000'
#  '2016-08-24T00:00:00.000000000' '2016-08-23T00:00:00.000000000'
#  '2016-08-22T00:00:00.000000000' '2016-08-19T00:00:00.000000000'
#  '2016-08-18T00:00:00.000000000' '2016-08-16T00:00:00.000000000'
#  '2016-08-12T00:00:00.000000000' '2016-08-10T00:00:00.000000000'
#  '2016-08-09T00:00:00.000000000' '2016-08-07T00:00:00.000000000'
#  '2016-08-05T00:00:00.000000000' '2016-08-03T00:00:00.000000000'
#  '2016-08-02T00:00:00.000000000' '2016-08-01T00:00:00.000000000'
#  '2016-07-29T00:00:00.000000000' '2016-07-28T00:00:00.000000000'
#  '2016-07-27T00:00:00.000000000' '2016-07-26T00:00:00.000000000'
#  '2016-07-24T00:00:00.000000000' '2016-07-22T00:00:00.000000000'
#  '2016-07-21T00:00:00.000000000' '2016-07-20T00:00:00.000000000'
#  '2016-07-19T00:00:00.000000000' '2016-07-17T00:00:00.000000000'
#  '2016-07-14T00:00:00.000000000' '2016-07-13T00:00:00.000000000'
#  '2016-07-12T00:00:00.000000000' '2016-07-11T00:00:00.000000000'
#  '2016-07-08T00:00:00.000000000' '2016-07-07T00:00:00.000000000'
#  '2016-07-05T00:00:00.000000000' '2016-07-01T00:00:00.000000000'
#  '2016-06-29T00:00:00.000000000' '2016-06-28T00:00:00.000000000'
#  '2016-06-27T00:00:00.000000000' '2016-06-24T00:00:00.000000000'
#  '2016-06-23T00:00:00.000000000' '2016-06-22T00:00:00.000000000'
#  '2016-06-21T00:00:00.000000000' '2016-06-20T00:00:00.000000000'
#  '2016-06-18T00:00:00.000000000' '2016-06-17T00:00:00.000000000'
#  '2016-06-14T00:00:00.000000000' '2016-06-13T00:00:00.000000000'
#  '2016-06-12T00:00:00.000000000' '2016-06-11T00:00:00.000000000'
#  '2016-06-10T00:00:00.000000000' '2016-06-09T00:00:00.000000000'
#  '2016-06-08T00:00:00.000000000']
